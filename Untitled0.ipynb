# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# %cd /content/gdrive/Shareddrives/HCC_mid
# Out:
# gdrive	sample_data
# /content/gdrive/Shareddrives/HCC_mid

# %%
# !ls
# Out:
# 0710763				  0710891-20210419T063203Z-001.zip
# 0710763-20210419T061842Z-001.zip  HCCmid.ipynb
# 0710789				  others
# 0710789_label.zip		  PyTorch-YOLOv3
# 0710891				  PyTorch-YOLOv3-20210419T065911Z-001.zip

# %%
# %cd PyTorch-YOLOv3
# Out:
# /content/gdrive/Shareddrives/HCC_mid/PyTorch-YOLOv3

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/Shareddrives/HCC_mid/PyTorch-YOLOv3/.git/

# %%
# !git add .

# %%
# !git config --global user.email "htcchen@ucdavis.edu"

# %%
# !git commit -m "First commit"
# Out:
# [master 2fcb908] First commit
#  4 files changed, 2 insertions(+), 8 deletions(-)
#  delete mode 100644 weights/darknet53.conv.74
#  delete mode 100644 weights/download_weights.sh

# %%
# !git remote add origin https://Hung-Ta-Chen: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@github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3
# Out:
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://Hung-Ta-Chen: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@github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3 (fetch)
# origin	https://Hung-Ta-Chen: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@github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3 (push)
# origin1	https://github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3 (fetch)
# origin1	https://github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3 (push)
# origin2	https://Hung-Ta-Chen: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@github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3 (fetch)
# origin2	https://Hung-Ta-Chen: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@github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3 (push)

# %%
# !git push origin master
# Out:
# Counting objects: 1123, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (478/478), done.
# Writing objects: 100% (1123/1123), 160.51 MiB | 12.46 MiB/s, done.
# Total 1123 (delta 650), reused 1080 (delta 628)
# remote: Resolving deltas: 100% (650/650), done.
# remote: error: Trace: bc4e776270020286a6ab2041e58750d7be7f95285e3606dd41212d9ea43d71a5
# remote: error: See http://git.io/iEPt8g for more information.
# remote: error: File weights/darknet53.conv.74 is 154.96 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3
#  ! [remote rejected] master -> master (pre-receive hook declined)
# error: failed to push some refs to 'https://Hung-Ta-Chen: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@github.com/Hung-Ta-Chen/UAV-object-detection-with-yolov3'

# %%
# !git rebase master
# Out:
# Cannot rebase: You have unstaged changes.
# Please commit or stash them.

# %%
# !git rm --cached
# Out:
# fatal: pathspec './weights/darknet53.conv.74' did not match any files

# %%
# !git remote rm origin
